# %%
from qiskit import IBMQ
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from pipeline.run_experiments import get_circuit

# %%
# numpy for linear algebra stuff
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
qc = get_circuit()

# %%
qc.draw()
# Out:
#      ┌───┐ ░                                                      ┌───┐┌───┐ ░ »
# q_0: ┤ H ├─░──────────────────────────────────────────────■────■──┤ X ├┤ X ├─░─»
#      └───┘ ░ ┌─────────┐                ┌───┐┌─────────┐┌─┴─┐  │  └─┬─┘└─┬─┘ ░ »
# q_1: ──────░─┤ Ry(π/2) ├──■─────────────┤ X ├┤ Ry(π/4) ├┤ X ├──┼────■────┼───░─»
#            ░ └─────────┘┌─┴─┐┌─────────┐└─┬─┘└─────────┘└───┘┌─┴─┐       │   ░ »
# q_2: ──────░────────────┤ X ├┤ Ry(π/4) ├──■──────────────────┤ X ├───────■───░─»
#            ░            └───┘└─────────┘                     └───┘           ░ »
# c: 3/══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «     ┌───┐ ░ ┌─┐
# «q_0: ┤ H ├─░─┤M├──────
# «     ├───┤ ░ └╥┘┌─┐
# «q_1: ┤ H ├─░──╫─┤M├───
# «     ├───┤ ░  ║ └╥┘┌─┐
# «q_2: ┤ H ├─░──╫──╫─┤M├
# «     └───┘ ░  ║  ║ └╥┘
# «c: 3/═════════╩══╩══╩═
# «              0  1  2

# %%
from qiskit import transpile

# %%
qc_transpiled =transpile(qc, basis_gates = ['cx', 'rz', 'id', 'sx', 'x'])

# %%
qc_transpiled.draw()
# Out:
# global phase: 7π/4
#      ┌─────────┐┌────┐┌─────────┐ ░                                   »
# q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░───────────────────────────────────»
#      └─────────┘└────┘└─────────┘ ░ ┌──────────┐┌────┐┌─────────┐     »
# q_1: ─────────────────────────────░─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──■──»
#                                   ░ └──────────┘└────┘└─────────┘┌─┴─┐»
# q_2: ─────────────────────────────░──────────────────────────────┤ X ├»
#                                   ░                              └───┘»
# c: 3/═════════════════════════════════════════════════════════════════»
#                                                                       »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «                                       ┌───┐┌────────┐┌────┐┌──────────┐┌────┐»
# ...

# %%
qc_2 = get_circuit(theta_2=np.pi/8+.01)

# %%
qc_2_transpiled = transpile(qc_2, basis_gates=['cx', 'rz', 'id', 'sx', 'x'])
qc_2_transpiled.draw()
# Out:
# global phase: 7π/4
#      ┌─────────┐┌────┐┌─────────┐ ░                                   »
# q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░───────────────────────────────────»
#      └─────────┘└────┘└─────────┘ ░ ┌──────────┐┌────┐┌─────────┐     »
# q_1: ─────────────────────────────░─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──■──»
#                                   ░ └──────────┘└────┘└─────────┘┌─┴─┐»
# q_2: ─────────────────────────────░──────────────────────────────┤ X ├»
#                                   ░                              └───┘»
# c: 3/═════════════════════════════════════════════════════════════════»
#                                                                       »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «                                         ┌───┐┌────────┐┌────┐┌────────────┐»
# ...

# %%
qc_my_transpile.draw()
# Out:
#      ┌───┐┌────┐┌──────────┐┌────┐┌───┐ ░                                   »
# q_0: ┤ X ├┤ √X ├┤ Rz(-π/2) ├┤ √X ├┤ X ├─░───────────────────────────────────»
#      └───┘└────┘└──────────┘└────┘└───┘ ░ ┌───┐┌────┐┌──────────┐┌────┐     »
# q_1: ───────────────────────────────────░─┤ X ├┤ √X ├┤ Rz(-π/2) ├┤ √X ├──■──»
#                                         ░ └───┘└────┘└──────────┘└────┘┌─┴─┐»
# q_2: ───────────────────────────────────░──────────────────────────────┤ X ├»
#                                         ░                              └───┘»
# c: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────■────■──»
# «                                 ┌───┐┌────┐┌─────────┐┌────┐┌───┐┌─┴─┐  │  »
# ...

# %%
qc_1 = get_circuit(bitval = 1)
qc_1_transpiled = transpile(qc_1, basis_gates=['cx', 'rz', 'id', 'sx', 'x'])
qc_1_transpiled.draw()
# Out:
# global phase: 5π/4
#      ┌─────────┐┌────┐┌──────────┐ ░                                   »
# q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/2) ├─░───────────────────────────────────»
#      └─────────┘└────┘└──────────┘ ░ ┌──────────┐┌────┐┌─────────┐     »
# q_1: ──────────────────────────────░─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──■──»
#                                    ░ └──────────┘└────┘└─────────┘┌─┴─┐»
# q_2: ──────────────────────────────░──────────────────────────────┤ X ├»
#                                    ░                              └───┘»
# c: 3/══════════════════════════════════════════════════════════════════»
#                                                                        »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «                                       ┌───┐┌────────┐┌────┐┌──────────┐┌────┐»
# ...

# %%
qc_1.draw()
# Out:
#      ┌───┐┌───┐ ░                                                      ┌───┐»
# q_0: ┤ X ├┤ H ├─░──────────────────────────────────────────────■────■──┤ X ├»
#      └───┘└───┘ ░ ┌─────────┐                ┌───┐┌─────────┐┌─┴─┐  │  └─┬─┘»
# q_1: ───────────░─┤ Ry(π/2) ├──■─────────────┤ X ├┤ Ry(π/4) ├┤ X ├──┼────■──»
#                 ░ └─────────┘┌─┴─┐┌─────────┐└─┬─┘└─────────┘└───┘┌─┴─┐     »
# q_2: ───────────░────────────┤ X ├┤ Ry(π/4) ├──■──────────────────┤ X ├─────»
#                 ░            └───┘└─────────┘                     └───┘     »
# c: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «     ┌───┐ ░ ┌───┐ ░ ┌─┐
# «q_0: ┤ X ├─░─┤ H ├─░─┤M├──────
# «     └─┬─┘ ░ ├───┤ ░ └╥┘┌─┐
# «q_1: ──┼───░─┤ H ├─░──╫─┤M├───
# «       │   ░ ├───┤ ░  ║ └╥┘┌─┐
# «q_2: ──■───░─┤ H ├─░──╫──╫─┤M├
# «           ░ └───┘ ░  ║  ║ └╥┘
# «c: 3/═════════════════╩══╩══╩═
# ...

# %%
qc_y = get_circuit(basis_send = 'Y', basis_measure = 'Y')
qc_y_transpiled = transpile(qc_y, basis_gates=['cx', 'rz', 'id', 'sx', 'x'])
qc_y_transpiled.draw()
# Out:
# global phase: 3π/4
#      ┌────────┐┌────┐┌────────┐ ░                                             »
# q_0: ┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├─░─────────────────────────────────────────────»
#      └────────┘└────┘└────────┘ ░ ┌──────────┐┌────┐┌─────────┐               »
# q_1: ───────────────────────────░─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──■────────────»
#                                 ░ └──────────┘└────┘└─────────┘┌─┴─┐┌────────┐»
# q_2: ───────────────────────────░──────────────────────────────┤ X ├┤ Rz(-π) ├»
#                                 ░                              └───┘└────────┘»
# c: 3/═════════════════════════════════════════════════════════════════════════»
#                                                                               »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────■────■──»
# ...

# %% [markdown]
# The measurement prep portion of the circuit matches my transpilation for the Y basis.

# %%
qc_y_1 = get_circuit(bitval = 1, basis_send = 'Y', basis_measure='Y')
qc_y_1_transpiled = transpile(qc_y_1, basis_gates=['cx', 'rz', 'id', 'sx', 'x'])
qc_y_1_transpiled.draw()
# Out:
# global phase: 7π/4
#      ┌────┐ ░                                                               »
# q_0: ┤ √X ├─░───────────────────────────────────────────────────────────────»
#      └────┘ ░ ┌──────────┐┌────┐┌─────────┐                                 »
# q_1: ───────░─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──■──────────────────────────────»
#             ░ └──────────┘└────┘└─────────┘┌─┴─┐┌────────┐┌────┐┌──────────┐»
# q_2: ───────░──────────────────────────────┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(3π/4) ├»
#             ░                              └───┘└────────┘└────┘└──────────┘»
# c: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                            ┌───┐┌───┐ ░ »
# «q_0: ───────────────────────────────────────────────■────■──┤ X ├┤ X ├─░─»
# «           ┌───┐┌────────┐┌────┐┌──────────┐┌────┐┌─┴─┐  │  └─┬─┘└─┬─┘ ░ »
# ...

# %% [markdown]
# The Alice prep for Y basis and bit value 1 matches my transpilation.

# %%
qc_my_transpile = get_circuit(gateset='ibm')
qc_my_tranpile_IBM = transpile(qc_my_transpile, basis_gates=['cx', 'rz', 'id', 'sx', 'x'])
qc_my_tranpile_IBM.draw()
# Out:
# global phase: 3π/4
#      ┌─────────┐┌────┐┌─────────┐ ░                                         »
# q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─░─────────────────────────────────────────»
#      └─────────┘└────┘└─────────┘ ░ ┌──────────┐┌────┐┌─────────┐           »
# q_1: ─────────────────────────────░─┤ Rz(-π/2) ├┤ √X ├┤ Rz(π/2) ├──■────────»
#                                   ░ └──────────┘└────┘└─────────┘┌─┴─┐┌────┐»
# q_2: ─────────────────────────────░──────────────────────────────┤ X ├┤ √X ├»
#                                   ░                              └───┘└────┘»
# c: 3/═══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                                      ┌───┐»
# «q_0: ─────────────────────────────────────────────────────────■────■──┤ X ├»
# «                           ┌───┐┌────┐┌─────────┐┌────┐┌───┐┌─┴─┐  │  └─┬─┘»
# ...
